# %%
#100 tosses with 4 consecutive heads
import random as rd
import numpy as np

#y =[]
def toss_coin():
    y.append(rd.randint(0,1))



trials = 100000
count = 0
for i in range(0,trials):
  y =[]
  for j in range(0,100):
    toss_coin()
  #print(len(range(0,100)))
  for j in range(0,97):
    if y[j] == 1 and y[j+1] ==1 and y[j+2] ==1 and y[j+3] ==1:
        count= count+1
        break
    else:
      count = count

print(count/trials)
#print(len(y))
# Out:
# 0.97365

# %%
#8 tosses with 2 consecutive heads
def toss_coin():
    y.append(rd.randint(0,1))



trials = 1000000
count = 0
for i in range(0,trials):
  y =[]
  for j in range(0,8):
    toss_coin()
  #print(len(range(0,100)))
  for j in range(0,7):
    if y[j] == 1 and y[j+1] ==1:
        count= count+1
        break
    else:
      count = count

print(count/trials)
# Out:
# 0.784287
